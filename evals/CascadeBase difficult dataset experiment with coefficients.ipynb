# %%
#ipynb config
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.cross_validation import train_test_split
from models.cascade_base import CascadeBase
from utils.visualizer import Visualizer
from IPython.display import SVG, display

import numpy as np
import matplotlib.pyplot as plt

import time
import pydot
import lasagne

plt.style.use('ggplot')

# %matplotlib notebook
# Out:
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN 5005)
# /home/apanin/anaconda/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
def get_hex_color(layer_type):
    """
    Determines the hex color for a layer.
    :parameters:
        - layer_type : string
            Class name of the layer
    :returns:
        - color : string containing a hex color for filling block.
    """
    COLORS = ['#4A88B3', '#98C1DE', '#6CA2C8', '#3173A2', '#17649B',
              '#FFBB60', '#FFDAA9', '#FFC981', '#FCAC41', '#F29416',
              '#C54AAA', '#E698D4', '#D56CBE', '#B72F99', '#B0108D',
              '#75DF54', '#B3F1A0', '#91E875', '#5DD637', '#3FCD12']

    hashed = int(hash(layer_type)) % 5

    if "conv" in layer_type.lower():
        return COLORS[:5][hashed]
    if layer_type in lasagne.layers.pool.__all__:
        return COLORS[5:10][hashed]
    if layer_type in lasagne.layers.recurrent.__all__:
        return COLORS[10:15][hashed]
    else:
        return COLORS[15:20][hashed]

def make_pydot_graph(layers, output_shape=True, verbose=False):
    """
    :parameters:
        - layers : list
            List of the layers, as obtained from lasagne.layers.get_all_layers
        - output_shape: (default `True`)
            If `True`, the output shape of each layer will be displayed.
        - verbose: (default `False`)
            If `True`, layer attributes like filter shape, stride, etc.
            will be displayed.
    :returns:
        - pydot_graph : PyDot object containing the graph
    """

    pydot_graph = pydot.Dot('Network', graph_type='digraph')
    pydot_nodes = {}
    pydot_edges = []
    for i, layer in enumerate(layers):
        layer_type = '{0}'.format(layer.__class__.__name__)
        layer_name = layer.name if layer.name is not None else ''
        key = repr(layer)
        label = layer_name + ' ' + layer_type
        color = get_hex_color(layer_type)
        if verbose:
            for attr in ['num_filters', 'num_units', 'ds',
                         'filter_shape', 'stride', 'strides', 'p']:
                if hasattr(layer, attr):
                    label += '\n{0}: {1}'.format(attr, getattr(layer, attr))
            if hasattr(layer, 'nonlinearity'):
                try:
                    nonlinearity = layer.nonlinearity.__name__
                except AttributeError:
                    nonlinearity = layer.nonlinearity.__class__.__name__
                label += '\nnonlinearity: {0}'.format(nonlinearity)

        if output_shape:
            label += '\nOutput shape: {0}'.format(layer.output_shape)

        pydot_nodes[key] = pydot.Node(
            key, label=label, shape='record', fillcolor=color, style='filled')

        if hasattr(layer, 'input_layers'):
            for input_layer in layer.input_layers:
                pydot_edges.append([repr(input_layer), key])

        if hasattr(layer, 'input_layer'):
            pydot_edges.append([repr(layer.input_layer), key])

    for node in pydot_nodes.values():
        pydot_graph.add_node(node)

    for edges in pydot_edges:
        pydot_graph.add_edge(
            pydot.Edge(pydot_nodes[edges[0]], pydot_nodes[edges[1]]))
    return pydot_graph

def iterate_minibatches(inputs, targets, batch_size):
    indices = np.arange(len(inputs))
    np.random.shuffle(indices)
    
    for start_idx in range(0, len(inputs) - batch_size + 1, batch_size):
        excerpt = indices[start_idx:start_idx + batch_size]

        yield inputs[excerpt], targets[excerpt]


def learn(nn,
          dataset,
          watches=['obj',
                   'recall',
                   'precision',
                   'accuracy',
                   'loss',
                   'sub_loss'],
          num_epochs=100,
          batch_size=50):
    '''
        num_epochs - amount of passes through the data
        batch_size - number of samples processed at each function call
        dataset - [X_train, X_val, y_train, y_val]
    '''
    # %matplotlib notebook
    
    X_train, X_val, y_train, y_val = dataset
    metrics_template = dict()
    
    metrics_sample = nn.evaluate(X_val[:2], y_val[:2])
    
    for metric_name, _ in metrics_sample.items():
        if metric_name == 'complexity_parts':
            metrics_template[metric_name] = [0] * len(metrics_sample[metric_name])
        else:
            metrics_template[metric_name] = 0
        
    visualizer = Visualizer(num_epochs,
                            metrics_template,
                            watches=watches)
    
    for epoch in range(num_epochs):
        # In each epoch, we do a full pass over the training data:
        start_time = time.time()
        
        train_measurements = dict(metrics_template)
        train_batches = 0

        for batch in iterate_minibatches(X_train, y_train, batch_size):
            inputs, targets = batch
            
            for metric_name, metric in nn.train(inputs, targets).items():
                if metric_name == 'complexity_parts':
                    for j in range(len(metrics_template[metric_name])):
                        train_measurements[metric_name][j] += metric[j]
                else: 
                    train_measurements[metric_name] += metric

            train_batches += 1
            
        for metric_name, metric in train_measurements.items():
            if metric_name == 'complexity_parts':
                for j in range(len(metrics_template[metric_name])):
                    train_measurements[metric_name][j] = metric[j] / train_batches
            else: 
                train_measurements[metric_name] = metric / train_batches

        # And a full pass over the validation data:
        val_measurements = dict(metrics_template)
        val_batches = 0

        for batch in iterate_minibatches(X_val, y_val, batch_size):
            inputs, targets = batch
            
            for metric_name, metric in nn.evaluate(inputs, targets).items():
                if metric_name == 'complexity_parts':
                    for j in range(len(metrics_template[metric_name])):
                        val_measurements[metric_name][j] += metric[j]
                else: 
                    val_measurements[metric_name] += metric

            val_batches += 1
            
        for metric_name, metric in val_measurements.items():
            if metric_name == 'complexity_parts':
                for j in range(len(metrics_template[metric_name])):
                    val_measurements[metric_name][j] = metric[j] / val_batches
            else: 
                val_measurements[metric_name] = metric / val_batches

        print('Epoch {} of {} took {:.3f}s'.format(epoch + 1, num_epochs, time.time() - start_time))
        visualizer.watch(train_measurements, val_measurements)
    visualizer.finish()
    
def draw(network):
    with open('../images/net.svg', 'w') as f:
        g = make_pydot_graph(lasagne.layers.get_all_layers(network))
        f.write(g.create_svg(f='svg'))

    display(SVG(filename='../images/net.svg'))

# %%
dataset = np.load('../data/not_bright/imgs_0001.npy')
targets = np.load('../data/not_bright/masks_0001.npy')

track_targets = targets.copy()
track_targets[track_targets <=0] = 0

# %%
X_y = train_test_split(dataset.reshape(-1, 1, 512, 512).astype(np.float32),
                       track_targets.reshape(-1, 1, 512, 512).astype(np.float32))

# %% [markdown]
# ## Retrain the network

# %%
dataset1 = np.load('../data/not_bright/imgs_0000.npy')
targets1 = np.load('../data/not_bright/masks_0000.npy')

track_targets1 = targets.copy()
track_targets1[track_targets1 <=0] = 0

# %%
dataset0 = dataset
track_targets0 = track_targets
targets0 = targets

dataset = np.stack((dataset0, dataset1))
targets = np.stack((targets0, targets1))
track_targets = np.stack((track_targets0, track_targets1))

# %%
X_y = train_test_split(dataset.reshape(-1, 1, 512, 512).astype(np.float32),
                       track_targets.reshape(-1, 1, 512, 512).astype(np.float32))

# %%
network = CascadeBase(img_shape=(512, 512),
                      learning_rate=1e-3,
                      c=1e-1,
                      c_complexity=1,
                      c_sub_objs=[1, 1, 1],
                      c_sub_obj_cs=[1e-1, 1e-1, 1e-1],
                      mul=True,
                      pool_sizes=[2, 2, 2, 2],
                      num_filters=[1, 1, 3, 6],
                      filter_sizes=[1, 3, 3, 3],
                      l2_c=1e-3)
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /home/apanin/.theano/compiledir_Linux-2.6-el6.x86_64-x86_64-with-redhat-6.6-Carbon-x86_64-2.7.11-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/apanin/.theano/compiledir_Linux-2.6-el6.x86_64-x86_64-with-redhat-6.6-Carbon-x86_64-2.7.11-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/apanin/.theano/compiledir_Linux-2.6-el6.x86_64-x86_64-with-redhat-6.6-Carbon-x86_64-2.7.11-64/lock_dir/lock

# %%
network.load('../weights', '3cascades_trained')

# %%
learn(network,
      X_y,
      watches=['obj',
               'recall',
               'precision',
               'accuracy',
               'loss',
               'sub_loss',
               'total_complexity',
               'complexity_parts'],
      num_epochs=1000,
      batch_size=50)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# Epoch 1 of 1000 took 28.681s
# /home/apanin/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_webagg_core.py:210: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   buff.shape = (renderer.height, renderer.width)
# Epoch 2 of 1000 took 28.844s
# Epoch 3 of 1000 took 30.660s
# Epoch 4 of 1000 took 30.052s
# Epoch 5 of 1000 took 30.410s
# Epoch 6 of 1000 took 29.960s
# Epoch 7 of 1000 took 30.005s
# Epoch 8 of 1000 took 29.923s
# Epoch 9 of 1000 took 30.109s
# Epoch 10 of 1000 took 29.902s
# Epoch 11 of 1000 took 29.859s
# Epoch 12 of 1000 took 29.800s
# Epoch 13 of 1000 took 29.788s
# Epoch 14 of 1000 took 29.869s
# Epoch 15 of 1000 took 29.999s
# Epoch 16 of 1000 took 29.642s
# Epoch 17 of 1000 took 29.734s
# Epoch 18 of 1000 took 29.595s
# Epoch 19 of 1000 took 29.776s
# Epoch 20 of 1000 took 29.728s
# Epoch 21 of 1000 took 29.728s
# Epoch 22 of 1000 took 29.614s
# Epoch 23 of 1000 took 29.663s
# Epoch 24 of 1000 took 29.702s
# Epoch 25 of 1000 took 29.760s
# Epoch 26 of 1000 took 29.850s
# Epoch 27 of 1000 took 29.571s
# Epoch 28 of 1000 took 29.638s
# Epoch 29 of 1000 took 29.688s
# Epoch 30 of 1000 took 29.659s
# Epoch 31 of 1000 took 29.615s
# Epoch 32 of 1000 took 29.726s
# Epoch 33 of 1000 took 29.774s
# Epoch 34 of 1000 took 29.651s
# Epoch 35 of 1000 took 29.648s
# Epoch 36 of 1000 took 29.681s
# Epoch 37 of 1000 took 29.692s
# Epoch 38 of 1000 took 29.633s
# Epoch 39 of 1000 took 29.716s
# Epoch 40 of 1000 took 29.903s
# Epoch 41 of 1000 took 29.631s
# Epoch 42 of 1000 took 29.683s
# Epoch 43 of 1000 took 29.686s
# Epoch 44 of 1000 took 29.678s
# Epoch 45 of 1000 took 29.667s
# Epoch 46 of 1000 took 29.653s
# Epoch 47 of 1000 took 29.735s
# Epoch 48 of 1000 took 29.633s
# Epoch 49 of 1000 took 29.804s
# Epoch 50 of 1000 took 29.658s
# Epoch 51 of 1000 took 29.695s
# Epoch 52 of 1000 took 29.696s
# Epoch 53 of 1000 took 29.676s
# Epoch 54 of 1000 took 29.707s
# Epoch 55 of 1000 took 29.988s
# Epoch 56 of 1000 took 29.697s
# Epoch 57 of 1000 took 29.652s
# Epoch 58 of 1000 took 29.851s
# Epoch 59 of 1000 took 30.065s
# Epoch 60 of 1000 took 29.640s
# Epoch 61 of 1000 took 29.766s
# Epoch 62 of 1000 took 29.778s
# Epoch 63 of 1000 took 29.581s
# Epoch 64 of 1000 took 29.787s
# Epoch 65 of 1000 took 29.798s
# Epoch 66 of 1000 took 29.671s
# Epoch 67 of 1000 took 30.114s
# Epoch 68 of 1000 took 29.684s
# Epoch 69 of 1000 took 29.828s
# Epoch 70 of 1000 took 30.070s
# Epoch 71 of 1000 took 29.691s
# Epoch 72 of 1000 took 29.741s
# Epoch 73 of 1000 took 29.699s
# Epoch 74 of 1000 took 29.685s
# Epoch 75 of 1000 took 29.688s
# Epoch 76 of 1000 took 29.732s
# Epoch 77 of 1000 took 29.740s
# Epoch 78 of 1000 took 29.663s
# Epoch 79 of 1000 took 29.770s
# Epoch 80 of 1000 took 29.710s
# Epoch 81 of 1000 took 30.004s
# Epoch 82 of 1000 took 29.670s
# Epoch 83 of 1000 took 29.785s
# Epoch 84 of 1000 took 29.794s
# Epoch 85 of 1000 took 29.695s
# Epoch 86 of 1000 took 29.939s
# Epoch 87 of 1000 took 29.772s
# Epoch 88 of 1000 took 29.718s
# Epoch 89 of 1000 took 29.907s
# Epoch 90 of 1000 took 29.645s
# Epoch 91 of 1000 took 30.125s
# Epoch 92 of 1000 took 29.668s
# Epoch 93 of 1000 took 29.852s
# Epoch 94 of 1000 took 29.754s
# Epoch 95 of 1000 took 29.806s
# Epoch 96 of 1000 took 29.949s
# Epoch 97 of 1000 took 29.770s
# Epoch 98 of 1000 took 29.711s
# Epoch 99 of 1000 took 29.843s
# Epoch 100 of 1000 took 30.057s
# Epoch 101 of 1000 took 29.691s
# Epoch 102 of 1000 took 29.657s
# Epoch 103 of 1000 took 29.709s
# Epoch 104 of 1000 took 29.983s
# Epoch 105 of 1000 took 29.719s
# Epoch 106 of 1000 took 29.683s
# Epoch 107 of 1000 took 29.813s
# Epoch 108 of 1000 took 29.830s
# Epoch 109 of 1000 took 29.709s
# Epoch 110 of 1000 took 29.777s
# Epoch 111 of 1000 took 29.743s
# Epoch 112 of 1000 took 29.847s
# Epoch 113 of 1000 took 29.719s
# Epoch 114 of 1000 took 29.740s
# Epoch 115 of 1000 took 29.653s
# Epoch 116 of 1000 took 29.654s
# Epoch 117 of 1000 took 29.713s
# Epoch 118 of 1000 took 29.668s
# Epoch 119 of 1000 took 29.671s
# Epoch 120 of 1000 took 29.720s
# Epoch 121 of 1000 took 29.674s
# Epoch 122 of 1000 took 29.697s
# Epoch 123 of 1000 took 29.751s
# Epoch 124 of 1000 took 29.650s
# Epoch 125 of 1000 took 29.716s
# Epoch 126 of 1000 took 29.689s
# Epoch 127 of 1000 took 29.719s
# Epoch 128 of 1000 took 29.726s
# Epoch 129 of 1000 took 29.749s
# Epoch 130 of 1000 took 29.698s
# Epoch 131 of 1000 took 29.704s
# Epoch 132 of 1000 took 29.772s
# Epoch 133 of 1000 took 29.634s
# Epoch 134 of 1000 took 29.841s
# Epoch 135 of 1000 took 29.842s
# Epoch 136 of 1000 took 29.722s
# Epoch 137 of 1000 took 29.812s
# Epoch 138 of 1000 took 29.652s
# Epoch 139 of 1000 took 29.827s
# Epoch 140 of 1000 took 29.789s
# Epoch 141 of 1000 took 29.731s
# Epoch 142 of 1000 took 29.852s
# Epoch 143 of 1000 took 29.727s
# Epoch 144 of 1000 took 29.699s
# Epoch 145 of 1000 took 29.860s
# Epoch 146 of 1000 took 29.685s
# Epoch 147 of 1000 took 29.729s
# Epoch 148 of 1000 took 29.778s
# Epoch 149 of 1000 took 29.771s
# Epoch 150 of 1000 took 29.652s
# Epoch 151 of 1000 took 29.769s
# Epoch 152 of 1000 took 29.684s
# Epoch 153 of 1000 took 29.655s
# Epoch 154 of 1000 took 29.667s
# Epoch 155 of 1000 took 29.670s
# Epoch 156 of 1000 took 29.715s
# Epoch 157 of 1000 took 29.638s
# Epoch 158 of 1000 took 29.709s
# Epoch 159 of 1000 took 29.738s
# Epoch 160 of 1000 took 29.683s
# Epoch 161 of 1000 took 29.631s
# Epoch 162 of 1000 took 29.726s
# Epoch 163 of 1000 took 29.712s
# Epoch 164 of 1000 took 29.707s
# Epoch 165 of 1000 took 29.765s
# Epoch 166 of 1000 took 29.863s
# Epoch 167 of 1000 took 29.728s
# Epoch 168 of 1000 took 29.551s
# Epoch 169 of 1000 took 29.670s
# Epoch 170 of 1000 took 29.716s
# Epoch 171 of 1000 took 29.745s
# Epoch 172 of 1000 took 29.628s
# Epoch 173 of 1000 took 29.674s
# Epoch 174 of 1000 took 29.646s
# Epoch 175 of 1000 took 29.720s
# Epoch 176 of 1000 took 29.742s
# Epoch 177 of 1000 took 29.695s
# Epoch 178 of 1000 took 29.826s
# Epoch 179 of 1000 took 29.829s
# Epoch 180 of 1000 took 29.717s
# Epoch 181 of 1000 took 29.680s
# Epoch 182 of 1000 took 29.744s
# Epoch 183 of 1000 took 29.656s
# Epoch 184 of 1000 took 29.824s
# Epoch 185 of 1000 took 29.742s
# Epoch 186 of 1000 took 29.641s
# Epoch 187 of 1000 took 29.888s
# Epoch 188 of 1000 took 29.667s
# Epoch 189 of 1000 took 29.694s
# Epoch 190 of 1000 took 29.680s
# Epoch 191 of 1000 took 29.716s
# Epoch 192 of 1000 took 29.715s
# Epoch 193 of 1000 took 29.692s
# Epoch 194 of 1000 took 29.611s
# Epoch 195 of 1000 took 29.769s
# Epoch 196 of 1000 took 29.923s
# Epoch 197 of 1000 took 29.743s
# Epoch 198 of 1000 took 29.700s
# Epoch 199 of 1000 took 29.669s
# Epoch 200 of 1000 took 29.661s
# Epoch 201 of 1000 took 29.752s
# Epoch 202 of 1000 took 29.726s
# Epoch 203 of 1000 took 29.428s
# Epoch 204 of 1000 took 29.802s
# Epoch 205 of 1000 took 29.596s
# Epoch 206 of 1000 took 29.702s
# Epoch 207 of 1000 took 29.788s
# Epoch 208 of 1000 took 29.586s
# Epoch 209 of 1000 took 29.609s
# Epoch 210 of 1000 took 29.715s
# Epoch 211 of 1000 took 29.675s
# Epoch 212 of 1000 took 29.645s
# Epoch 213 of 1000 took 29.749s
# Epoch 214 of 1000 took 29.643s
# Epoch 215 of 1000 took 29.753s
# Epoch 216 of 1000 took 29.703s
# Epoch 217 of 1000 took 29.952s
# Epoch 218 of 1000 took 29.657s
# Epoch 219 of 1000 took 29.700s
# Epoch 220 of 1000 took 29.755s
# Epoch 221 of 1000 took 29.956s
# Epoch 222 of 1000 took 29.793s
# Epoch 223 of 1000 took 29.754s
# Epoch 224 of 1000 took 29.903s
# Epoch 225 of 1000 took 29.857s
# Epoch 226 of 1000 took 29.746s
# Epoch 227 of 1000 took 29.703s
# Epoch 228 of 1000 took 29.648s
# Epoch 229 of 1000 took 29.846s
# Epoch 230 of 1000 took 29.852s
# Epoch 231 of 1000 took 29.706s
# Epoch 232 of 1000 took 29.726s
# Epoch 233 of 1000 took 29.995s
# Epoch 234 of 1000 took 29.572s
# Epoch 235 of 1000 took 29.807s
# Epoch 236 of 1000 took 29.716s
# Epoch 237 of 1000 took 29.676s
# Epoch 238 of 1000 took 29.740s
# Epoch 239 of 1000 took 29.697s
# Epoch 240 of 1000 took 29.753s
# Epoch 241 of 1000 took 29.970s
# Epoch 242 of 1000 took 29.830s
# Epoch 243 of 1000 took 29.651s
# Epoch 244 of 1000 took 29.697s
# Epoch 245 of 1000 took 29.699s
# Epoch 246 of 1000 took 29.834s
# Epoch 247 of 1000 took 29.627s
# Epoch 248 of 1000 took 29.748s
# Epoch 249 of 1000 took 29.698s
# Epoch 250 of 1000 took 29.760s
# Epoch 251 of 1000 took 29.710s
# Epoch 252 of 1000 took 29.774s
# Epoch 253 of 1000 took 29.798s
# Epoch 254 of 1000 took 29.611s
# Epoch 255 of 1000 took 29.708s
# Epoch 256 of 1000 took 29.663s
# Epoch 257 of 1000 took 29.733s
# Epoch 258 of 1000 took 29.700s
# Epoch 259 of 1000 took 29.722s
# Epoch 260 of 1000 took 29.758s
# Epoch 261 of 1000 took 29.672s
# Epoch 262 of 1000 took 29.760s
# Epoch 263 of 1000 took 29.709s
# Epoch 264 of 1000 took 30.140s
# Epoch 265 of 1000 took 29.602s
# Epoch 266 of 1000 took 29.659s
# Epoch 267 of 1000 took 29.700s
# Epoch 268 of 1000 took 29.703s
# Epoch 269 of 1000 took 29.726s
# Epoch 270 of 1000 took 30.037s
# Epoch 271 of 1000 took 29.729s
# Epoch 272 of 1000 took 29.798s
# Epoch 273 of 1000 took 29.628s
# Epoch 274 of 1000 took 29.674s
# Epoch 275 of 1000 took 29.773s
# Epoch 276 of 1000 took 29.850s
# Epoch 277 of 1000 took 29.736s
# Epoch 278 of 1000 took 29.631s
# Epoch 279 of 1000 took 29.808s
# Epoch 280 of 1000 took 29.758s
# Epoch 281 of 1000 took 29.993s
# Epoch 282 of 1000 took 29.683s
# Epoch 283 of 1000 took 29.611s
# Epoch 284 of 1000 took 29.688s
# Epoch 285 of 1000 took 29.662s
# Epoch 286 of 1000 took 29.651s
# Epoch 287 of 1000 took 29.675s
# Epoch 288 of 1000 took 29.699s
# Epoch 289 of 1000 took 29.716s
# Epoch 290 of 1000 took 29.752s
# Epoch 291 of 1000 took 29.681s
# Epoch 292 of 1000 took 29.672s
# Epoch 293 of 1000 took 29.698s
# Epoch 294 of 1000 took 29.701s
# Epoch 295 of 1000 took 29.714s
# Epoch 296 of 1000 took 29.813s
# Epoch 297 of 1000 took 29.826s
# Epoch 298 of 1000 took 29.760s
# Epoch 299 of 1000 took 29.795s
# Epoch 300 of 1000 took 29.715s
# Epoch 301 of 1000 took 29.771s
# Epoch 302 of 1000 took 29.682s
# Epoch 303 of 1000 took 29.795s
# Epoch 304 of 1000 took 29.639s
# Epoch 305 of 1000 took 29.714s
# Epoch 306 of 1000 took 29.635s
# Epoch 307 of 1000 took 29.730s
# Epoch 308 of 1000 took 29.595s
# Epoch 309 of 1000 took 29.655s
# Epoch 310 of 1000 took 29.872s
# Epoch 311 of 1000 took 29.687s
# Epoch 312 of 1000 took 29.817s
# Epoch 313 of 1000 took 29.816s
# Epoch 314 of 1000 took 29.639s
# Epoch 315 of 1000 took 29.835s
# Epoch 316 of 1000 took 29.928s
# Epoch 317 of 1000 took 29.725s
# Epoch 318 of 1000 took 29.702s
# Epoch 319 of 1000 took 29.689s
# Epoch 320 of 1000 took 29.805s
# Epoch 321 of 1000 took 29.637s
# Epoch 322 of 1000 took 29.710s
# Epoch 323 of 1000 took 29.664s
# Epoch 324 of 1000 took 29.650s
# Epoch 325 of 1000 took 29.756s
# Epoch 326 of 1000 took 29.980s
# Epoch 327 of 1000 took 29.717s
# Epoch 328 of 1000 took 29.675s
# Epoch 329 of 1000 took 29.742s
# Epoch 330 of 1000 took 29.759s
# Epoch 331 of 1000 took 29.845s
# Epoch 332 of 1000 took 29.724s
# Epoch 333 of 1000 took 29.664s
# Epoch 334 of 1000 took 29.876s
# Epoch 335 of 1000 took 29.878s
# Epoch 336 of 1000 took 29.940s
# Epoch 337 of 1000 took 29.604s
# Epoch 338 of 1000 took 29.831s
# Epoch 339 of 1000 took 29.688s
# Epoch 340 of 1000 took 29.620s
# Epoch 341 of 1000 took 29.682s
# Epoch 342 of 1000 took 29.643s
# Epoch 343 of 1000 took 29.636s
# Epoch 344 of 1000 took 29.714s
# Epoch 345 of 1000 took 29.647s
# Epoch 346 of 1000 took 29.630s
# Epoch 347 of 1000 took 29.661s
# Epoch 348 of 1000 took 29.724s
# Epoch 349 of 1000 took 29.705s
# Epoch 350 of 1000 took 29.739s
# Epoch 351 of 1000 took 29.607s
# Epoch 352 of 1000 took 29.799s
# Epoch 353 of 1000 took 29.712s
# Epoch 354 of 1000 took 29.663s
# Epoch 355 of 1000 took 29.658s
# Epoch 356 of 1000 took 29.728s
# Epoch 357 of 1000 took 29.682s
# Epoch 358 of 1000 took 29.727s
# Epoch 359 of 1000 took 29.644s
# Epoch 360 of 1000 took 29.662s
# Epoch 361 of 1000 took 29.657s
# Epoch 362 of 1000 took 29.678s
# Epoch 363 of 1000 took 29.681s
# Epoch 364 of 1000 took 29.788s
# Epoch 365 of 1000 took 29.901s
# Epoch 366 of 1000 took 29.648s
# Epoch 367 of 1000 took 29.796s
# Epoch 368 of 1000 took 29.595s
# Epoch 369 of 1000 took 29.719s
# Epoch 370 of 1000 took 29.768s
# Epoch 371 of 1000 took 29.662s
# Epoch 372 of 1000 took 29.731s
# Epoch 373 of 1000 took 29.683s
# Epoch 374 of 1000 took 29.764s
# Epoch 375 of 1000 took 29.730s
# Epoch 376 of 1000 took 29.745s
# Epoch 377 of 1000 took 29.735s
# Epoch 378 of 1000 took 29.772s
# Epoch 379 of 1000 took 29.690s
# Epoch 380 of 1000 took 29.752s
# Epoch 381 of 1000 took 29.717s
# Epoch 382 of 1000 took 29.861s
# Epoch 383 of 1000 took 29.710s
# Epoch 384 of 1000 took 29.719s
# Epoch 385 of 1000 took 29.802s
# Epoch 386 of 1000 took 29.774s
# Epoch 387 of 1000 took 29.682s
# Epoch 388 of 1000 took 29.763s
# Epoch 389 of 1000 took 29.748s
# Epoch 390 of 1000 took 29.728s
# Epoch 391 of 1000 took 29.778s
# Epoch 392 of 1000 took 29.790s
# Epoch 393 of 1000 took 29.765s
# Epoch 394 of 1000 took 29.929s
# Epoch 395 of 1000 took 29.716s
# Epoch 396 of 1000 took 29.734s
# Epoch 397 of 1000 took 29.775s
# Epoch 398 of 1000 took 29.717s
# Epoch 399 of 1000 took 29.681s
# Epoch 400 of 1000 took 29.894s
# Epoch 401 of 1000 took 30.019s
# Epoch 402 of 1000 took 29.866s
# Epoch 403 of 1000 took 29.685s
# Epoch 404 of 1000 took 29.613s
# Epoch 405 of 1000 took 29.632s
# Epoch 406 of 1000 took 29.644s
# Epoch 407 of 1000 took 29.757s
# Epoch 408 of 1000 took 29.641s
# Epoch 409 of 1000 took 29.619s
# Epoch 410 of 1000 took 29.679s
# Epoch 411 of 1000 took 29.568s
# Epoch 412 of 1000 took 29.710s
# Epoch 413 of 1000 took 29.647s
# Epoch 414 of 1000 took 29.619s
# Epoch 415 of 1000 took 29.620s
# Epoch 416 of 1000 took 29.607s
# Epoch 417 of 1000 took 29.612s
# Epoch 418 of 1000 took 29.677s
# Epoch 419 of 1000 took 29.743s
# Epoch 420 of 1000 took 29.631s
# Epoch 421 of 1000 took 29.658s
# Epoch 422 of 1000 took 29.801s
# Epoch 423 of 1000 took 29.656s
# Epoch 424 of 1000 took 29.530s
# Epoch 425 of 1000 took 29.710s
# Epoch 426 of 1000 took 29.694s
# Epoch 427 of 1000 took 29.654s
# Epoch 428 of 1000 took 29.829s
# Epoch 429 of 1000 took 29.614s
# Epoch 430 of 1000 took 29.595s
# Epoch 431 of 1000 took 29.659s
# Epoch 432 of 1000 took 29.676s
# Epoch 433 of 1000 took 29.716s
# Epoch 434 of 1000 took 29.771s
# Epoch 435 of 1000 took 29.897s
# Epoch 436 of 1000 took 29.535s
# Epoch 437 of 1000 took 29.645s
# Epoch 438 of 1000 took 29.683s
# Epoch 439 of 1000 took 29.605s
# Epoch 440 of 1000 took 29.741s
# Epoch 441 of 1000 took 29.816s
# Epoch 442 of 1000 took 29.587s
# Epoch 443 of 1000 took 29.916s
# Epoch 444 of 1000 took 29.634s
# Epoch 445 of 1000 took 29.653s
# Epoch 446 of 1000 took 30.073s
# Epoch 447 of 1000 took 29.675s
# Epoch 448 of 1000 took 29.660s
# Epoch 449 of 1000 took 29.768s
# Epoch 450 of 1000 took 29.637s
# Epoch 451 of 1000 took 29.696s
# Epoch 452 of 1000 took 29.709s
# Epoch 453 of 1000 took 29.696s
# Epoch 454 of 1000 took 29.667s
# Epoch 455 of 1000 took 29.629s
# Epoch 456 of 1000 took 29.852s
# Epoch 457 of 1000 took 29.669s
# Epoch 458 of 1000 took 29.799s
# Epoch 459 of 1000 took 29.851s
# Epoch 460 of 1000 took 29.713s
# Epoch 461 of 1000 took 29.635s
# Epoch 462 of 1000 took 29.790s
# Epoch 463 of 1000 took 29.864s
# Epoch 464 of 1000 took 29.938s
# Epoch 465 of 1000 took 29.641s
# Epoch 466 of 1000 took 29.702s
# Epoch 467 of 1000 took 29.765s
# Epoch 468 of 1000 took 29.664s
# Epoch 469 of 1000 took 29.701s
# Epoch 470 of 1000 took 29.755s
# Epoch 471 of 1000 took 29.600s
# Epoch 472 of 1000 took 29.666s
# Epoch 473 of 1000 took 29.674s
# Epoch 474 of 1000 took 29.759s
# Epoch 475 of 1000 took 29.685s
# Epoch 476 of 1000 took 29.679s
# Epoch 477 of 1000 took 29.758s
# Epoch 478 of 1000 took 29.675s
# Epoch 479 of 1000 took 29.696s
# Epoch 480 of 1000 took 29.690s
# Epoch 481 of 1000 took 29.801s
# Epoch 482 of 1000 took 29.771s
# Epoch 483 of 1000 took 29.740s
# Epoch 484 of 1000 took 29.831s
# Epoch 485 of 1000 took 29.696s
# Epoch 486 of 1000 took 29.956s
# Epoch 487 of 1000 took 29.676s
# Epoch 488 of 1000 took 29.705s
# Epoch 489 of 1000 took 29.659s
# Epoch 490 of 1000 took 29.716s
# Epoch 491 of 1000 took 29.745s
# Epoch 492 of 1000 took 29.838s
# Epoch 493 of 1000 took 29.653s
# Epoch 494 of 1000 took 29.702s
# Epoch 495 of 1000 took 29.716s
# Epoch 496 of 1000 took 29.862s
# Epoch 497 of 1000 took 29.706s
# Epoch 498 of 1000 took 29.717s
# Epoch 499 of 1000 took 29.802s
# Epoch 500 of 1000 took 29.742s
# Epoch 501 of 1000 took 29.699s
# Epoch 502 of 1000 took 29.689s
# Epoch 503 of 1000 took 29.809s
# Epoch 504 of 1000 took 29.720s
# Epoch 505 of 1000 took 29.707s
# Epoch 506 of 1000 took 29.809s
# Epoch 507 of 1000 took 29.694s
# Epoch 508 of 1000 took 29.689s
# Epoch 509 of 1000 took 29.774s
# Epoch 510 of 1000 took 29.728s
# Epoch 511 of 1000 took 29.808s
# Epoch 512 of 1000 took 30.057s
# Epoch 513 of 1000 took 29.643s
# Epoch 514 of 1000 took 29.928s
# Epoch 515 of 1000 took 29.699s
# Epoch 516 of 1000 took 29.720s
# Epoch 517 of 1000 took 29.724s
# Epoch 518 of 1000 took 29.680s
# Epoch 519 of 1000 took 29.895s
# Epoch 520 of 1000 took 29.612s
# Epoch 521 of 1000 took 29.892s
# Epoch 522 of 1000 took 29.719s
# Epoch 523 of 1000 took 29.730s
# Epoch 524 of 1000 took 29.741s
# Epoch 525 of 1000 took 29.741s
# Epoch 526 of 1000 took 29.691s
# Epoch 527 of 1000 took 29.737s
# Epoch 528 of 1000 took 29.760s
# Epoch 529 of 1000 took 29.640s
# Epoch 530 of 1000 took 30.087s
# Epoch 531 of 1000 took 29.734s
# Epoch 532 of 1000 took 29.745s
# Epoch 533 of 1000 took 29.671s
# Epoch 534 of 1000 took 29.740s
# Epoch 535 of 1000 took 29.803s
# Epoch 536 of 1000 took 29.676s
# Epoch 537 of 1000 took 30.032s
# Epoch 538 of 1000 took 29.831s
# Epoch 539 of 1000 took 29.770s
# Epoch 540 of 1000 took 29.745s
# Epoch 541 of 1000 took 29.749s
# Epoch 542 of 1000 took 29.593s
# Epoch 543 of 1000 took 29.735s
# Epoch 544 of 1000 took 29.724s
# Epoch 545 of 1000 took 29.755s
# Epoch 546 of 1000 took 29.707s
# Epoch 547 of 1000 took 29.704s
# Epoch 548 of 1000 took 29.848s
# Epoch 549 of 1000 took 29.711s
# Epoch 550 of 1000 took 29.644s
# Epoch 551 of 1000 took 29.788s
# Epoch 552 of 1000 took 29.639s
# Epoch 553 of 1000 took 29.847s
# Epoch 554 of 1000 took 29.856s
# Epoch 555 of 1000 took 29.752s
# Epoch 556 of 1000 took 29.671s
# Epoch 557 of 1000 took 29.778s
# Epoch 558 of 1000 took 29.681s
# Epoch 559 of 1000 took 29.779s
# Epoch 560 of 1000 took 29.836s
# Epoch 561 of 1000 took 29.710s
# Epoch 562 of 1000 took 29.826s
# Epoch 563 of 1000 took 29.848s
# Epoch 564 of 1000 took 29.697s
# Epoch 565 of 1000 took 29.665s
# Epoch 566 of 1000 took 29.679s
# Epoch 567 of 1000 took 29.526s
# Epoch 568 of 1000 took 29.735s
# Epoch 569 of 1000 took 29.518s
# Epoch 570 of 1000 took 29.615s
# Epoch 571 of 1000 took 29.937s
# Epoch 572 of 1000 took 29.587s
# Epoch 573 of 1000 took 29.494s
# Epoch 574 of 1000 took 29.953s
# Epoch 575 of 1000 took 29.519s
# Epoch 576 of 1000 took 29.615s
# Epoch 577 of 1000 took 29.448s
# Epoch 578 of 1000 took 29.601s
# Epoch 579 of 1000 took 29.531s
# Epoch 580 of 1000 took 29.626s
# Epoch 581 of 1000 took 29.615s
# Epoch 582 of 1000 took 29.544s
# Epoch 583 of 1000 took 29.502s
# Epoch 584 of 1000 took 29.644s
# Epoch 585 of 1000 took 29.696s
# Epoch 586 of 1000 took 29.596s
# Epoch 587 of 1000 took 29.534s
# Epoch 588 of 1000 took 29.509s
# Epoch 589 of 1000 took 29.513s
# Epoch 590 of 1000 took 29.562s
# Epoch 591 of 1000 took 29.569s
# Epoch 592 of 1000 took 29.586s
# Epoch 593 of 1000 took 29.467s
# Epoch 594 of 1000 took 29.559s
# Epoch 595 of 1000 took 29.700s
# Epoch 596 of 1000 took 29.863s
# Epoch 597 of 1000 took 29.705s
# Epoch 598 of 1000 took 29.551s
# Epoch 599 of 1000 took 29.510s
# Epoch 600 of 1000 took 29.574s
# Epoch 601 of 1000 took 29.534s
# Epoch 602 of 1000 took 29.635s
# Epoch 603 of 1000 took 29.504s
# Epoch 604 of 1000 took 29.511s
# Epoch 605 of 1000 took 29.511s
# Epoch 606 of 1000 took 29.618s
# Epoch 607 of 1000 took 29.518s
# Epoch 608 of 1000 took 29.581s
# Epoch 609 of 1000 took 29.754s
# Epoch 610 of 1000 took 29.531s
# Epoch 611 of 1000 took 29.541s
# Epoch 612 of 1000 took 29.595s
# Epoch 613 of 1000 took 29.488s
# Epoch 614 of 1000 took 29.536s
# Epoch 615 of 1000 took 29.590s
# Epoch 616 of 1000 took 29.487s
# Epoch 617 of 1000 took 29.551s
# Epoch 618 of 1000 took 29.542s
# Epoch 619 of 1000 took 29.609s
# Epoch 620 of 1000 took 29.910s
# Epoch 621 of 1000 took 29.486s
# Epoch 622 of 1000 took 29.490s
# Epoch 623 of 1000 took 29.526s
# Epoch 624 of 1000 took 29.870s
# Epoch 625 of 1000 took 29.565s
# Epoch 626 of 1000 took 29.541s
# Epoch 627 of 1000 took 29.569s
# Epoch 628 of 1000 took 29.797s
# Epoch 629 of 1000 took 29.533s
# Epoch 630 of 1000 took 29.649s
# Epoch 631 of 1000 took 29.475s
# Epoch 632 of 1000 took 29.519s
# Epoch 633 of 1000 took 29.521s
# Epoch 634 of 1000 took 29.598s
# Epoch 635 of 1000 took 29.532s
# Epoch 636 of 1000 took 29.612s
# Epoch 637 of 1000 took 29.472s
# Epoch 638 of 1000 took 29.542s
# Epoch 639 of 1000 took 29.590s
# Epoch 640 of 1000 took 29.475s
# Epoch 641 of 1000 took 29.528s
# Epoch 642 of 1000 took 29.558s
# Epoch 643 of 1000 took 29.682s
# Epoch 644 of 1000 took 29.473s
# Epoch 645 of 1000 took 29.572s
# Epoch 646 of 1000 took 29.469s
# Epoch 647 of 1000 took 29.616s
# Epoch 648 of 1000 took 29.446s
# Epoch 649 of 1000 took 29.513s
# Epoch 650 of 1000 took 29.464s
# Epoch 651 of 1000 took 29.724s
# Epoch 652 of 1000 took 29.580s
# Epoch 653 of 1000 took 29.533s
# Epoch 654 of 1000 took 29.607s
# Epoch 655 of 1000 took 29.515s
# Epoch 656 of 1000 took 29.490s
# Epoch 657 of 1000 took 29.699s
# Epoch 658 of 1000 took 29.525s
# Epoch 659 of 1000 took 29.473s
# Epoch 660 of 1000 took 29.722s
# Epoch 661 of 1000 took 29.583s
# Epoch 662 of 1000 took 29.796s
# Epoch 663 of 1000 took 29.531s
# Epoch 664 of 1000 took 29.501s
# Epoch 665 of 1000 took 29.606s
# Epoch 666 of 1000 took 29.493s
# Epoch 667 of 1000 took 29.506s
# Epoch 668 of 1000 took 29.550s
# Epoch 669 of 1000 took 29.583s
# Epoch 670 of 1000 took 29.535s
# Epoch 671 of 1000 took 29.477s
# Epoch 672 of 1000 took 29.531s
# Epoch 673 of 1000 took 29.551s
# Epoch 674 of 1000 took 29.716s
# Epoch 675 of 1000 took 29.624s
# Epoch 676 of 1000 took 29.485s
# Epoch 677 of 1000 took 29.526s
# Epoch 678 of 1000 took 29.546s
# Epoch 679 of 1000 took 29.746s
# Epoch 680 of 1000 took 29.573s
# Epoch 681 of 1000 took 29.451s
# Epoch 682 of 1000 took 29.542s
# Epoch 683 of 1000 took 29.694s
# Epoch 684 of 1000 took 29.865s
# Epoch 685 of 1000 took 29.644s
# Epoch 686 of 1000 took 29.670s
# Epoch 687 of 1000 took 29.555s
# Epoch 688 of 1000 took 29.549s
# Epoch 689 of 1000 took 29.533s
# Epoch 690 of 1000 took 29.518s
# Epoch 691 of 1000 took 29.583s
# Epoch 692 of 1000 took 29.600s
# Epoch 693 of 1000 took 29.749s
# Epoch 694 of 1000 took 29.481s
# Epoch 695 of 1000 took 29.635s
# Epoch 696 of 1000 took 29.482s
# Epoch 697 of 1000 took 29.541s
# Epoch 698 of 1000 took 29.547s
# Epoch 699 of 1000 took 29.666s
# Epoch 700 of 1000 took 29.616s
# Epoch 701 of 1000 took 29.528s
# Epoch 702 of 1000 took 29.596s
# Epoch 703 of 1000 took 29.518s
# Epoch 704 of 1000 took 29.482s
# Epoch 705 of 1000 took 29.628s
# Epoch 706 of 1000 took 29.910s
# Epoch 707 of 1000 took 29.485s
# Epoch 708 of 1000 took 29.917s
# Epoch 709 of 1000 took 29.569s
# Epoch 710 of 1000 took 29.620s
# Epoch 711 of 1000 took 29.535s
# Epoch 712 of 1000 took 29.480s
# Epoch 713 of 1000 took 29.650s
# Epoch 714 of 1000 took 29.860s
# Epoch 715 of 1000 took 29.456s
# Epoch 716 of 1000 took 29.505s
# Epoch 717 of 1000 took 29.656s
# Epoch 718 of 1000 took 29.832s
# Epoch 719 of 1000 took 29.833s
# Epoch 720 of 1000 took 29.485s
# Epoch 721 of 1000 took 29.657s
# Epoch 722 of 1000 took 29.512s
# Epoch 723 of 1000 took 29.458s
# Epoch 724 of 1000 took 29.583s
# Epoch 725 of 1000 took 29.449s
# Epoch 726 of 1000 took 29.550s
# Epoch 727 of 1000 took 29.573s
# Epoch 728 of 1000 took 29.672s
# Epoch 729 of 1000 took 29.592s
# Epoch 730 of 1000 took 29.438s
# Epoch 731 of 1000 took 29.474s
# Epoch 732 of 1000 took 29.921s
# Epoch 733 of 1000 took 29.516s
# Epoch 734 of 1000 took 29.560s
# Epoch 735 of 1000 took 29.574s
# Epoch 736 of 1000 took 29.601s
# Epoch 737 of 1000 took 29.428s
# Epoch 738 of 1000 took 29.673s
# Epoch 739 of 1000 took 29.494s
# Epoch 740 of 1000 took 29.482s
# Epoch 741 of 1000 took 29.616s
# Epoch 742 of 1000 took 29.446s
# Epoch 743 of 1000 took 29.498s
# Epoch 744 of 1000 took 29.630s
# Epoch 745 of 1000 took 29.511s
# Epoch 746 of 1000 took 29.559s
# Epoch 747 of 1000 took 29.590s
# Epoch 748 of 1000 took 29.487s
# Epoch 749 of 1000 took 29.509s
# Epoch 750 of 1000 took 29.447s
# Epoch 751 of 1000 took 29.708s
# Epoch 752 of 1000 took 29.563s
# Epoch 753 of 1000 took 29.557s
# Epoch 754 of 1000 took 29.480s
# Epoch 755 of 1000 took 29.537s
# Epoch 756 of 1000 took 29.599s
# Epoch 757 of 1000 took 29.621s
# Epoch 758 of 1000 took 29.595s
# Epoch 759 of 1000 took 29.523s
# Epoch 760 of 1000 took 29.558s
# Epoch 761 of 1000 took 29.537s
# Epoch 762 of 1000 took 29.627s
# Epoch 763 of 1000 took 29.716s
# Epoch 764 of 1000 took 29.465s
# Epoch 765 of 1000 took 29.511s
# Epoch 766 of 1000 took 29.610s
# Epoch 767 of 1000 took 29.502s
# Epoch 768 of 1000 took 29.559s
# Epoch 769 of 1000 took 29.572s
# Epoch 770 of 1000 took 29.518s
# Epoch 771 of 1000 took 29.506s
# Epoch 772 of 1000 took 29.512s
# Epoch 773 of 1000 took 29.575s
# Epoch 774 of 1000 took 29.616s
# Epoch 775 of 1000 took 29.473s
# Epoch 776 of 1000 took 29.485s
# Epoch 777 of 1000 took 29.496s
# Epoch 778 of 1000 took 29.779s
# Epoch 779 of 1000 took 29.556s
# Epoch 780 of 1000 took 29.458s
# Epoch 781 of 1000 took 29.596s
# Epoch 782 of 1000 took 29.469s
# Epoch 783 of 1000 took 29.569s
# Epoch 784 of 1000 took 29.679s
# Epoch 785 of 1000 took 29.573s
# Epoch 786 of 1000 took 29.434s
# Epoch 787 of 1000 took 29.543s
# Epoch 788 of 1000 took 29.604s
# Epoch 789 of 1000 took 29.595s
# Epoch 790 of 1000 took 29.509s
# Epoch 791 of 1000 took 29.958s
# Epoch 792 of 1000 took 29.422s
# Epoch 793 of 1000 took 29.560s
# Epoch 794 of 1000 took 29.640s
# Epoch 795 of 1000 took 29.779s
# Epoch 796 of 1000 took 29.737s
# Epoch 797 of 1000 took 29.552s
# Epoch 798 of 1000 took 29.684s
# Epoch 799 of 1000 took 29.530s
# Epoch 800 of 1000 took 29.581s
# Epoch 801 of 1000 took 29.433s
# Epoch 802 of 1000 took 29.616s
# Epoch 803 of 1000 took 29.495s
# Epoch 804 of 1000 took 29.539s
# Epoch 805 of 1000 took 29.517s
# Epoch 806 of 1000 took 29.468s
# Epoch 807 of 1000 took 29.541s
# Epoch 808 of 1000 took 29.445s
# Epoch 809 of 1000 took 29.790s
# Epoch 810 of 1000 took 29.510s
# Epoch 811 of 1000 took 29.850s
# Epoch 812 of 1000 took 29.398s
# Epoch 813 of 1000 took 29.497s
# Epoch 814 of 1000 took 29.409s
# Epoch 815 of 1000 took 29.555s
# Epoch 816 of 1000 took 29.533s
# Epoch 817 of 1000 took 29.436s
# Epoch 818 of 1000 took 29.459s
# Epoch 819 of 1000 took 29.543s
# Epoch 820 of 1000 took 29.451s
# Epoch 821 of 1000 took 29.603s
# Epoch 822 of 1000 took 29.553s
# Epoch 823 of 1000 took 29.586s
# Epoch 824 of 1000 took 29.489s
# Epoch 825 of 1000 took 29.568s
# Epoch 826 of 1000 took 29.761s
# Epoch 827 of 1000 took 29.623s
# Epoch 828 of 1000 took 29.481s
# Epoch 829 of 1000 took 29.466s
# Epoch 830 of 1000 took 29.523s
# Epoch 831 of 1000 took 29.512s
# Epoch 832 of 1000 took 29.631s
# Epoch 833 of 1000 took 29.661s
# Epoch 834 of 1000 took 29.542s
# Epoch 835 of 1000 took 29.772s
# Epoch 836 of 1000 took 29.507s
# Epoch 837 of 1000 took 29.478s
# Epoch 838 of 1000 took 29.488s
# Epoch 839 of 1000 took 29.555s
# Epoch 840 of 1000 took 29.509s
# Epoch 841 of 1000 took 29.486s
# Epoch 842 of 1000 took 29.459s
# Epoch 843 of 1000 took 29.845s
# Epoch 844 of 1000 took 29.646s
# Epoch 845 of 1000 took 29.493s
# Epoch 846 of 1000 took 29.464s
# Epoch 847 of 1000 took 29.808s
# Epoch 848 of 1000 took 29.494s
# Epoch 849 of 1000 took 29.525s
# Epoch 850 of 1000 took 29.505s
# Epoch 851 of 1000 took 29.752s
# Epoch 852 of 1000 took 29.633s
# Epoch 853 of 1000 took 29.524s
# Epoch 854 of 1000 took 29.492s
# Epoch 855 of 1000 took 29.553s
# Epoch 856 of 1000 took 29.493s
# Epoch 857 of 1000 took 29.453s
# Epoch 858 of 1000 took 29.477s
# Epoch 859 of 1000 took 29.669s
# Epoch 860 of 1000 took 29.655s
# Epoch 861 of 1000 took 29.442s
# Epoch 862 of 1000 took 29.882s
# Epoch 863 of 1000 took 29.444s
# Epoch 864 of 1000 took 29.605s
# Epoch 865 of 1000 took 29.562s
# Epoch 866 of 1000 took 29.988s
# Epoch 867 of 1000 took 29.455s
# Epoch 868 of 1000 took 29.489s
# Epoch 869 of 1000 took 29.561s
# Epoch 870 of 1000 took 29.718s
# Epoch 871 of 1000 took 29.674s
# Epoch 872 of 1000 took 29.498s
# Epoch 873 of 1000 took 29.551s
# Epoch 874 of 1000 took 29.576s
# Epoch 875 of 1000 took 29.469s
# Epoch 876 of 1000 took 29.433s
# Epoch 877 of 1000 took 29.493s
# Epoch 878 of 1000 took 29.511s
# Epoch 879 of 1000 took 29.520s
# Epoch 880 of 1000 took 29.457s
# Epoch 881 of 1000 took 29.773s
# Epoch 882 of 1000 took 29.593s
# Epoch 883 of 1000 took 29.933s
# Epoch 884 of 1000 took 29.443s
# Epoch 885 of 1000 took 29.493s
# Epoch 886 of 1000 took 29.676s
# Epoch 887 of 1000 took 29.482s
# Epoch 888 of 1000 took 29.478s
# Epoch 889 of 1000 took 29.500s
# Epoch 890 of 1000 took 29.453s
# Epoch 891 of 1000 took 29.553s
# Epoch 892 of 1000 took 29.629s
# Epoch 893 of 1000 took 29.396s
# Epoch 894 of 1000 took 29.495s
# Epoch 895 of 1000 took 29.610s
# Epoch 896 of 1000 took 29.473s
# Epoch 897 of 1000 took 29.656s
# Epoch 898 of 1000 took 29.498s
# Epoch 899 of 1000 took 29.857s
# Epoch 900 of 1000 took 29.485s
# Epoch 901 of 1000 took 29.505s
# Epoch 902 of 1000 took 29.649s
# Epoch 903 of 1000 took 29.571s
# Epoch 904 of 1000 took 29.430s
# Epoch 905 of 1000 took 29.531s
# Epoch 906 of 1000 took 29.434s
# Epoch 907 of 1000 took 29.525s
# Epoch 908 of 1000 took 29.361s
# Epoch 909 of 1000 took 29.484s
# Epoch 910 of 1000 took 29.654s
# Epoch 911 of 1000 took 29.492s
# Epoch 912 of 1000 took 29.482s
# Epoch 913 of 1000 took 29.479s
# Epoch 914 of 1000 took 29.531s
# Epoch 915 of 1000 took 29.547s
# Epoch 916 of 1000 took 29.550s
# Epoch 917 of 1000 took 29.533s
# Epoch 918 of 1000 took 29.640s
# Epoch 919 of 1000 took 29.531s
# Epoch 920 of 1000 took 29.468s
# Epoch 921 of 1000 took 29.536s
# Epoch 922 of 1000 took 29.576s
# Epoch 923 of 1000 took 29.552s
# Epoch 924 of 1000 took 29.509s
# Epoch 925 of 1000 took 29.472s
# Epoch 926 of 1000 took 29.586s
# Epoch 927 of 1000 took 29.581s
# Epoch 928 of 1000 took 29.429s
# Epoch 929 of 1000 took 29.488s
# Epoch 930 of 1000 took 29.448s
# Epoch 931 of 1000 took 29.715s
# Epoch 932 of 1000 took 29.589s
# Epoch 933 of 1000 took 29.452s
# Epoch 934 of 1000 took 29.599s
# Epoch 935 of 1000 took 29.447s
# Epoch 936 of 1000 took 29.881s
# Epoch 937 of 1000 took 29.460s
# Epoch 938 of 1000 took 29.472s
# Epoch 939 of 1000 took 29.702s
# Epoch 940 of 1000 took 29.661s
# Epoch 941 of 1000 took 29.642s
# Epoch 942 of 1000 took 29.530s
# Epoch 943 of 1000 took 29.475s
# Epoch 944 of 1000 took 29.537s
# Epoch 945 of 1000 took 29.545s
# Epoch 946 of 1000 took 29.463s
# Epoch 947 of 1000 took 29.633s
# Epoch 948 of 1000 took 29.494s
# Epoch 949 of 1000 took 29.572s
# Epoch 950 of 1000 took 29.607s
# Epoch 951 of 1000 took 29.643s
# Epoch 952 of 1000 took 29.572s
# Epoch 953 of 1000 took 29.520s
# Epoch 954 of 1000 took 29.568s
# Epoch 955 of 1000 took 29.435s
# Epoch 956 of 1000 took 29.668s
# Epoch 957 of 1000 took 29.812s
# Epoch 958 of 1000 took 29.601s
# Epoch 959 of 1000 took 29.663s
# Epoch 960 of 1000 took 29.546s
# Epoch 961 of 1000 took 29.552s
# Epoch 962 of 1000 took 29.468s
# Epoch 963 of 1000 took 29.468s
# Epoch 964 of 1000 took 29.469s
# Epoch 965 of 1000 took 29.484s
# Epoch 966 of 1000 took 29.451s
# Epoch 967 of 1000 took 29.552s
# Epoch 968 of 1000 took 29.543s
# Epoch 969 of 1000 took 29.509s
# Epoch 970 of 1000 took 29.697s
# Epoch 971 of 1000 took 29.472s
# Epoch 972 of 1000 took 29.524s
# Epoch 973 of 1000 took 29.533s
# Epoch 974 of 1000 took 29.568s
# Epoch 975 of 1000 took 29.842s
# Epoch 976 of 1000 took 29.588s
# Epoch 977 of 1000 took 29.492s
# Epoch 978 of 1000 took 29.563s
# Epoch 979 of 1000 took 29.557s
# Epoch 980 of 1000 took 29.513s
# Epoch 981 of 1000 took 29.490s
# Epoch 982 of 1000 took 29.571s
# Epoch 983 of 1000 took 29.579s
# Epoch 984 of 1000 took 29.523s
# Epoch 985 of 1000 took 29.463s
# Epoch 986 of 1000 took 29.556s
# Epoch 987 of 1000 took 29.818s
# Epoch 988 of 1000 took 29.534s
# Epoch 989 of 1000 took 29.491s
# Epoch 990 of 1000 took 29.497s
# Epoch 991 of 1000 took 29.520s
# Epoch 992 of 1000 took 29.887s
# Epoch 993 of 1000 took 29.509s
# Epoch 994 of 1000 took 29.467s
# Epoch 995 of 1000 took 29.723s
# Epoch 996 of 1000 took 29.463s
# Epoch 997 of 1000 took 29.877s
# Epoch 998 of 1000 took 29.459s
# Epoch 999 of 1000 took 29.515s
# Epoch 1000 of 1000 took 29.451s

# %% [markdown]
# # Check results

# %%
# %matplotlib inline
i = np.random.choice(X_y[-1].shape[0])

plt.imshow(X_y[1][i][0])
plt.colorbar()
plt.show()

plt.imshow(X_y[-1][i][0], interpolation='none')
plt.colorbar()
plt.show()

prediction = network.predict(X_y[1][i-1:i].astype(np.float32))

plt.imshow(prediction[0, 0], interpolation='none', cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

plt.imshow(prediction[0, 0] < 0.5, interpolation='none', cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

plt.imshow(prediction[0, 0] >= 0.5, interpolation='none', cmap=plt.cm.Reds)
plt.colorbar()
plt.show()

# %% [markdown]
# # Precision Vs Recall

# %%
import theano
get_target = theano.function([network.targets], lasagne.layers.get_output(network.target_pool_layers[-1]))

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

x_val = X_y[1][:100]
y_val = X_y[-1][:100]

prediction = network.predict(x_val)
target = get_target(y_val)

precision, recall, thr = precision_recall_curve(target.ravel(), prediction.ravel())
average_precision = average_precision_score(target.ravel(), prediction.ravel())

# Plot Precision-Recall curve
plt.clf()
plt.plot(recall, precision, label='Precision-Recall curve')
plt.plot(np.arange(thr.shape[0]) / (thr.shape[0] + 1e-6), thr, label='Threshold')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall example: AUC={0:0.2f}'.format(average_precision))
plt.legend(loc='best')
plt.show()

# %%
precision[10000]
# Out:
# 0.10983144181048955

# %%
thr[10000]
# Out:
# 0.011953057

# %%
recall[10000]
# Out:
# 0.99543517954960437

# %% [markdown]
# # Final train

# %%
learn(network,
      X_y,
      watches=['obj',
               'recall',
               'precision',
               'accuracy',
               'loss',
               'sub_loss',
               'total_complexity',
               'complexity_parts'],
      num_epochs=1000,
      batch_size=50)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# Epoch 1 of 1000 took 28.806s
# Epoch 2 of 1000 took 28.808s
# Epoch 3 of 1000 took 29.136s
# Epoch 4 of 1000 took 29.167s
# Epoch 5 of 1000 took 29.236s
# Epoch 6 of 1000 took 29.338s
# Epoch 7 of 1000 took 29.294s
# Epoch 8 of 1000 took 29.398s

# %%
network.save('../weights', '3cascades_long_train')
