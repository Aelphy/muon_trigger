# %%
#ipynb config
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.cross_validation import train_test_split
from models.cascade_base import CascadeBase
from utils.visualizer import Visualizer
from IPython.display import SVG, display

import numpy as np
import matplotlib.pyplot as plt

import time
import pydot
import lasagne

plt.style.use('ggplot')

# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN 5005)

# %%
def get_hex_color(layer_type):
    """
    Determines the hex color for a layer.
    :parameters:
        - layer_type : string
            Class name of the layer
    :returns:
        - color : string containing a hex color for filling block.
    """
    COLORS = ['#4A88B3', '#98C1DE', '#6CA2C8', '#3173A2', '#17649B',
              '#FFBB60', '#FFDAA9', '#FFC981', '#FCAC41', '#F29416',
              '#C54AAA', '#E698D4', '#D56CBE', '#B72F99', '#B0108D',
              '#75DF54', '#B3F1A0', '#91E875', '#5DD637', '#3FCD12']

    hashed = int(hash(layer_type)) % 5

    if "conv" in layer_type.lower():
        return COLORS[:5][hashed]
    if layer_type in lasagne.layers.pool.__all__:
        return COLORS[5:10][hashed]
    if layer_type in lasagne.layers.recurrent.__all__:
        return COLORS[10:15][hashed]
    else:
        return COLORS[15:20][hashed]

def make_pydot_graph(layers, output_shape=True, verbose=False):
    """
    :parameters:
        - layers : list
            List of the layers, as obtained from lasagne.layers.get_all_layers
        - output_shape: (default `True`)
            If `True`, the output shape of each layer will be displayed.
        - verbose: (default `False`)
            If `True`, layer attributes like filter shape, stride, etc.
            will be displayed.
    :returns:
        - pydot_graph : PyDot object containing the graph
    """

    pydot_graph = pydot.Dot('Network', graph_type='digraph')
    pydot_nodes = {}
    pydot_edges = []
    for i, layer in enumerate(layers):
        layer_type = '{0}'.format(layer.__class__.__name__)
        layer_name = layer.name if layer.name is not None else ''
        key = repr(layer)
        label = layer_name + ' ' + layer_type
        color = get_hex_color(layer_type)
        if verbose:
            for attr in ['num_filters', 'num_units', 'ds',
                         'filter_shape', 'stride', 'strides', 'p']:
                if hasattr(layer, attr):
                    label += '\n{0}: {1}'.format(attr, getattr(layer, attr))
            if hasattr(layer, 'nonlinearity'):
                try:
                    nonlinearity = layer.nonlinearity.__name__
                except AttributeError:
                    nonlinearity = layer.nonlinearity.__class__.__name__
                label += '\nnonlinearity: {0}'.format(nonlinearity)

        if output_shape:
            label += '\nOutput shape: {0}'.format(layer.output_shape)

        pydot_nodes[key] = pydot.Node(
            key, label=label, shape='record', fillcolor=color, style='filled')

        if hasattr(layer, 'input_layers'):
            for input_layer in layer.input_layers:
                pydot_edges.append([repr(input_layer), key])

        if hasattr(layer, 'input_layer'):
            pydot_edges.append([repr(layer.input_layer), key])

    for node in pydot_nodes.values():
        pydot_graph.add_node(node)

    for edges in pydot_edges:
        pydot_graph.add_edge(
            pydot.Edge(pydot_nodes[edges[0]], pydot_nodes[edges[1]]))
    return pydot_graph

def iterate_minibatches(inputs, targets, batch_size):
    indices = np.arange(len(inputs))
    np.random.shuffle(indices)
    
    for start_idx in range(0, len(inputs) - batch_size + 1, batch_size):
        excerpt = indices[start_idx:start_idx + batch_size]

        yield inputs[excerpt], targets[excerpt]


def learn(nn,
          dataset,
          watches=['obj',
                   'recall',
                   'precision',
                   'accuracy',
                   'loss',
                   'sub_loss'],
          num_epochs=100,
          batch_size=50):
    '''
        num_epochs - amount of passes through the data
        batch_size - number of samples processed at each function call
        dataset - [X_train, X_val, y_train, y_val]
    '''
    # %matplotlib notebook
    
    X_train, X_val, y_train, y_val = dataset
    metrics_template = dict()
    
    metrics_sample = nn.evaluate(X_val[:2], y_val[:2])
    
    for metric_name, _ in metrics_sample.items():
        if metric_name == 'complexity_parts':
            metrics_template[metric_name] = [0] * len(metrics_sample[metric_name])
        else:
            metrics_template[metric_name] = 0
        
    visualizer = Visualizer(num_epochs,
                            metrics_template,
                            watches=watches)
    
    for epoch in range(num_epochs):
        # In each epoch, we do a full pass over the training data:
        start_time = time.time()
        
        train_measurements = dict(metrics_template)
        train_batches = 0

        for batch in iterate_minibatches(X_train, y_train, batch_size):
            inputs, targets = batch
            
            for metric_name, metric in nn.train(inputs, targets).items():
                if metric_name == 'complexity_parts':
                    for j in range(len(metrics_template[metric_name])):
                        train_measurements[metric_name][j] += metric[j]
                else: 
                    train_measurements[metric_name] += metric

            train_batches += 1
            
        for metric_name, metric in train_measurements.items():
            if metric_name == 'complexity_parts':
                for j in range(len(metrics_template[metric_name])):
                    train_measurements[metric_name][j] = metric[j] / train_batches
            else: 
                train_measurements[metric_name] = metric / train_batches

        # And a full pass over the validation data:
        val_measurements = dict(metrics_template)
        val_batches = 0

        for batch in iterate_minibatches(X_val, y_val, batch_size):
            inputs, targets = batch
            
            for metric_name, metric in nn.evaluate(inputs, targets).items():
                if metric_name == 'complexity_parts':
                    for j in range(len(metrics_template[metric_name])):
                        val_measurements[metric_name][j] += metric[j]
                else: 
                    val_measurements[metric_name] += metric

            val_batches += 1
            
        for metric_name, metric in val_measurements.items():
            if metric_name == 'complexity_parts':
                for j in range(len(metrics_template[metric_name])):
                    val_measurements[metric_name][j] = metric[j] / val_batches
            else: 
                val_measurements[metric_name] = metric / val_batches

        print('Epoch {} of {} took {:.3f}s'.format(epoch + 1, num_epochs, time.time() - start_time))
        visualizer.watch(train_measurements, val_measurements)
    visualizer.finish()
    
def draw(network):
    with open('../images/net.svg', 'w') as f:
        g = make_pydot_graph(lasagne.layers.get_all_layers(network))
        f.write(g.create_svg(f='svg'))

    display(SVG(filename='../images/net.svg'))

# %%
datasets = []
targets = []

for i in range(1):
    print i
    datasets.append(np.load('../data/imgs_{}.npy?dl=0'.format(str(i).zfill(4))).reshape(-1, 1, 512, 512))
    targets.append(np.load('../data/masks_{}.npy?dl=0'.format(str(i).zfill(4))).reshape(-1, 1, 512, 512))

dataset = np.vstack(datasets)
targets = np.vstack(targets)

track_targets = targets.copy()
track_targets[track_targets <=0] = 0
# Out:
# 0

# %%
X_y = train_test_split(dataset, track_targets)

# %% [markdown]
# ## Train the network

# %%
network = CascadeBase(img_shape=(512, 512),
                      learning_rate=1e-3,
                      c=1e-1,
                      c_complexity=0,
                      c_sub_objs=[5e-2, 1e-1, 5e-1, 1],
                      c_sub_obj_cs=[5e-3, 1e-2, 5e-2, 1e-1],
                      mul=True,
                      pool_sizes=[2, 2, 2, 2],
                      num_filters=[1, 1, 3, 6],
                      filter_sizes=[1, 3, 3, 3],
                      l2_c=1e-4)
# Out:
# INFO (theano.gof.compilelock): Waiting for existing lock by process '1849' (I am process '16363')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/apanin/.theano/compiledir_Linux-2.6-el6.x86_64-x86_64-with-redhat-6.6-Carbon-x86_64-2.7.11-64/lock_dir

# %%
network.load('../weights', '3cascades_not_clear_trained800')

# %%
learn(network,
      X_y,
      watches=['obj',
               'recall',
               'precision',
               'accuracy',
               'loss',
               'sub_loss',
               'total_complexity',
               'complexity_parts'],
      num_epochs=800,
      batch_size=50)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# Epoch 1 of 800 took 77.007s
# Epoch 2 of 800 took 77.694s
# Epoch 3 of 800 took 78.727s
# Epoch 4 of 800 took 79.275s
# Epoch 5 of 800 took 79.559s
# Epoch 6 of 800 took 79.653s
# Epoch 7 of 800 took 79.374s
# Epoch 8 of 800 took 79.223s
# Epoch 9 of 800 took 79.268s
# Epoch 10 of 800 took 78.832s
# Epoch 11 of 800 took 79.061s
# Epoch 12 of 800 took 78.717s
# Epoch 13 of 800 took 78.894s
# Epoch 14 of 800 took 79.069s
# Epoch 15 of 800 took 79.296s
# Epoch 16 of 800 took 78.897s
# Epoch 17 of 800 took 79.260s
# Epoch 18 of 800 took 79.181s
# Epoch 19 of 800 took 79.030s
# Epoch 20 of 800 took 79.040s
# Epoch 21 of 800 took 79.061s
# Epoch 22 of 800 took 79.085s
# Epoch 23 of 800 took 79.133s
# Epoch 24 of 800 took 78.739s
# Epoch 25 of 800 took 79.228s
# Epoch 26 of 800 took 78.731s
# Epoch 27 of 800 took 79.358s
# Epoch 28 of 800 took 78.933s
# Epoch 29 of 800 took 79.044s
# Epoch 30 of 800 took 78.804s
# Epoch 31 of 800 took 79.109s
# Epoch 32 of 800 took 78.745s
# Epoch 33 of 800 took 78.847s
# Epoch 34 of 800 took 79.071s
# Epoch 35 of 800 took 78.877s
# Epoch 36 of 800 took 78.937s
# Epoch 37 of 800 took 78.831s
# Epoch 38 of 800 took 78.570s
# Epoch 39 of 800 took 79.010s
# Epoch 40 of 800 took 78.944s
# Epoch 41 of 800 took 78.816s
# Epoch 42 of 800 took 79.080s
# Epoch 43 of 800 took 78.966s
# Epoch 44 of 800 took 78.796s
# Epoch 45 of 800 took 78.532s
# Epoch 46 of 800 took 78.994s
# Epoch 47 of 800 took 78.836s
# Epoch 48 of 800 took 78.984s
# Epoch 49 of 800 took 78.663s
# Epoch 50 of 800 took 78.936s
# Epoch 51 of 800 took 78.942s
# Epoch 52 of 800 took 78.930s
# Epoch 53 of 800 took 78.704s
# Epoch 54 of 800 took 78.850s
# Epoch 55 of 800 took 78.930s
# Epoch 56 of 800 took 78.890s
# Epoch 57 of 800 took 78.865s
# Epoch 58 of 800 took 78.940s
# Epoch 59 of 800 took 78.943s
# Epoch 60 of 800 took 78.911s
# Epoch 61 of 800 took 78.883s
# Epoch 62 of 800 took 78.986s
# Epoch 63 of 800 took 78.653s
# Epoch 64 of 800 took 79.049s
# Epoch 65 of 800 took 78.906s
# Epoch 66 of 800 took 78.658s
# Epoch 67 of 800 took 79.006s
# Epoch 68 of 800 took 78.818s
# Epoch 69 of 800 took 78.980s
# Epoch 70 of 800 took 78.662s
# Epoch 71 of 800 took 78.698s
# Epoch 72 of 800 took 78.817s
# Epoch 73 of 800 took 79.013s
# Epoch 74 of 800 took 79.150s
# Epoch 75 of 800 took 79.004s
# Epoch 76 of 800 took 79.044s
# Epoch 77 of 800 took 78.488s
# Epoch 78 of 800 took 78.945s
# Epoch 79 of 800 took 78.925s
# Epoch 80 of 800 took 79.075s
# Epoch 81 of 800 took 79.006s
# Epoch 82 of 800 took 78.784s
# Epoch 83 of 800 took 78.945s
# Epoch 84 of 800 took 78.935s
# Epoch 85 of 800 took 79.189s
# Epoch 86 of 800 took 79.009s
# Epoch 87 of 800 took 78.899s
# Epoch 88 of 800 took 78.914s
# Epoch 89 of 800 took 78.919s
# Epoch 90 of 800 took 78.946s
# Epoch 91 of 800 took 79.108s
# Epoch 92 of 800 took 78.239s
# Epoch 93 of 800 took 79.024s
# Epoch 94 of 800 took 78.753s
# Epoch 95 of 800 took 78.888s
# Epoch 96 of 800 took 78.912s
# Epoch 97 of 800 took 78.878s
# Epoch 98 of 800 took 78.974s
# Epoch 99 of 800 took 79.057s
# Epoch 100 of 800 took 78.882s
# Epoch 101 of 800 took 78.883s
# Epoch 102 of 800 took 78.922s
# Epoch 103 of 800 took 78.935s
# Epoch 104 of 800 took 78.221s
# Epoch 105 of 800 took 78.923s
# Epoch 106 of 800 took 78.862s
# Epoch 107 of 800 took 78.923s
# Epoch 108 of 800 took 78.765s
# Epoch 109 of 800 took 78.885s
# Epoch 110 of 800 took 78.871s
# Epoch 111 of 800 took 79.096s
# Epoch 112 of 800 took 78.687s
# Epoch 113 of 800 took 78.993s
# Epoch 114 of 800 took 78.844s
# Epoch 115 of 800 took 78.704s
# Epoch 116 of 800 took 78.957s
# Epoch 117 of 800 took 78.738s
# Epoch 118 of 800 took 79.086s
# Epoch 119 of 800 took 79.056s
# Epoch 120 of 800 took 79.114s
# Epoch 121 of 800 took 79.108s
# Epoch 122 of 800 took 78.949s
# Epoch 123 of 800 took 79.112s
# Epoch 124 of 800 took 79.045s
# Epoch 125 of 800 took 79.031s
# Epoch 126 of 800 took 78.791s
# Epoch 127 of 800 took 78.695s
# Epoch 128 of 800 took 78.744s
# Epoch 129 of 800 took 79.032s
# Epoch 130 of 800 took 78.926s
# Epoch 131 of 800 took 78.925s
# Epoch 132 of 800 took 79.000s
# Epoch 133 of 800 took 78.526s
# Epoch 134 of 800 took 79.127s
# Epoch 135 of 800 took 78.722s
# Epoch 136 of 800 took 79.075s
# Epoch 137 of 800 took 78.898s
# Epoch 138 of 800 took 79.058s
# Epoch 139 of 800 took 78.946s
# Epoch 140 of 800 took 79.044s
# Epoch 141 of 800 took 78.857s
# Epoch 142 of 800 took 79.030s
# Epoch 143 of 800 took 78.826s
# Epoch 144 of 800 took 79.006s
# Epoch 145 of 800 took 78.768s
# Epoch 146 of 800 took 78.747s
# Epoch 147 of 800 took 79.041s
# Epoch 148 of 800 took 79.122s
# Epoch 149 of 800 took 79.125s
# Epoch 150 of 800 took 78.907s
# Epoch 151 of 800 took 79.001s
# Epoch 152 of 800 took 78.910s
# Epoch 153 of 800 took 78.951s
# Epoch 154 of 800 took 78.635s
# Epoch 155 of 800 took 78.777s
# Epoch 156 of 800 took 78.696s
# Epoch 157 of 800 took 78.714s
# Epoch 158 of 800 took 78.443s
# Epoch 159 of 800 took 78.687s
# Epoch 160 of 800 took 78.519s
# Epoch 161 of 800 took 78.120s
# Epoch 162 of 800 took 78.837s
# Epoch 163 of 800 took 78.662s
# Epoch 164 of 800 took 78.493s
# Epoch 165 of 800 took 78.685s
# Epoch 166 of 800 took 78.592s
# Epoch 167 of 800 took 78.457s
# Epoch 168 of 800 took 78.466s
# Epoch 169 of 800 took 78.520s
# Epoch 170 of 800 took 78.505s
# Epoch 171 of 800 took 78.538s
# Epoch 172 of 800 took 78.395s
# Epoch 173 of 800 took 78.381s
# Epoch 174 of 800 took 78.482s
# Epoch 175 of 800 took 78.428s
# Epoch 176 of 800 took 78.330s
# Epoch 177 of 800 took 78.232s
# Epoch 178 of 800 took 78.274s
# Epoch 179 of 800 took 78.497s
# Epoch 180 of 800 took 78.368s
# Epoch 181 of 800 took 78.288s
# Epoch 182 of 800 took 78.266s
# Epoch 183 of 800 took 78.085s
# Epoch 184 of 800 took 78.279s
# Epoch 185 of 800 took 78.279s
# Epoch 186 of 800 took 78.306s
# Epoch 187 of 800 took 78.282s
# Epoch 188 of 800 took 78.143s
# Epoch 189 of 800 took 77.873s
# Epoch 190 of 800 took 78.323s
# Epoch 191 of 800 took 77.858s
# Epoch 192 of 800 took 78.398s
# Epoch 193 of 800 took 78.267s
# Epoch 194 of 800 took 78.371s
# Epoch 195 of 800 took 78.341s
# Epoch 196 of 800 took 78.254s
# Epoch 197 of 800 took 78.293s
# Epoch 198 of 800 took 78.224s
# Epoch 199 of 800 took 78.339s
# Epoch 200 of 800 took 78.290s
# Epoch 201 of 800 took 78.219s
# Epoch 202 of 800 took 78.368s
# Epoch 203 of 800 took 78.255s
# Epoch 204 of 800 took 77.892s
# Epoch 205 of 800 took 78.335s
# Epoch 206 of 800 took 78.283s
# Epoch 207 of 800 took 78.266s
# Epoch 208 of 800 took 78.157s
# Epoch 209 of 800 took 78.207s
# Epoch 210 of 800 took 78.264s
# Epoch 211 of 800 took 78.342s
# Epoch 212 of 800 took 78.422s
# Epoch 213 of 800 took 78.350s
# Epoch 214 of 800 took 78.354s
# Epoch 215 of 800 took 78.241s
# Epoch 216 of 800 took 78.392s
# Epoch 217 of 800 took 78.389s
# Epoch 218 of 800 took 78.439s
# Epoch 219 of 800 took 78.347s
# Epoch 220 of 800 took 78.469s
# Epoch 221 of 800 took 78.516s
# Epoch 222 of 800 took 78.080s
# Epoch 223 of 800 took 78.482s
# Epoch 224 of 800 took 78.395s
# Epoch 225 of 800 took 78.217s
# Epoch 226 of 800 took 78.356s
# Epoch 227 of 800 took 78.050s
# Epoch 228 of 800 took 78.269s
# Epoch 229 of 800 took 78.306s
# Epoch 230 of 800 took 78.282s
# Epoch 231 of 800 took 78.281s
# Epoch 232 of 800 took 78.312s
# Epoch 233 of 800 took 78.230s
# Epoch 234 of 800 took 78.349s
# Epoch 235 of 800 took 77.925s
# Epoch 236 of 800 took 78.452s
# Epoch 237 of 800 took 78.286s
# Epoch 238 of 800 took 78.252s
# Epoch 239 of 800 took 78.315s
# Epoch 240 of 800 took 78.151s
# Epoch 241 of 800 took 78.598s
# Epoch 242 of 800 took 78.544s
# Epoch 243 of 800 took 78.459s
# Epoch 244 of 800 took 78.362s
# Epoch 245 of 800 took 78.222s
# Epoch 246 of 800 took 78.330s
# Epoch 247 of 800 took 78.433s
# Epoch 248 of 800 took 78.464s
# Epoch 249 of 800 took 78.268s
# Epoch 250 of 800 took 78.088s
# Epoch 251 of 800 took 78.111s
# Epoch 252 of 800 took 78.451s
# Epoch 253 of 800 took 78.137s
# Epoch 254 of 800 took 78.313s
# Epoch 255 of 800 took 78.420s
# Epoch 256 of 800 took 77.949s
# Epoch 257 of 800 took 78.281s
# Epoch 258 of 800 took 78.328s
# Epoch 259 of 800 took 78.231s
# Epoch 260 of 800 took 78.301s
# Epoch 261 of 800 took 78.278s
# Epoch 262 of 800 took 78.277s
# Epoch 263 of 800 took 78.283s
# Epoch 264 of 800 took 78.284s
# Epoch 265 of 800 took 78.153s
# Epoch 266 of 800 took 78.369s
# Epoch 267 of 800 took 78.216s
# Epoch 268 of 800 took 78.333s
# Epoch 269 of 800 took 78.158s
# Epoch 270 of 800 took 78.425s
# Epoch 271 of 800 took 78.540s
# Epoch 272 of 800 took 78.481s
# Epoch 273 of 800 took 78.273s
# Epoch 274 of 800 took 78.328s
# Epoch 275 of 800 took 78.456s
# Epoch 276 of 800 took 77.830s
# Epoch 277 of 800 took 78.321s
# Epoch 278 of 800 took 78.223s
# Epoch 279 of 800 took 78.129s
# Epoch 280 of 800 took 78.453s
# Epoch 281 of 800 took 77.885s
# Epoch 282 of 800 took 78.503s
# Epoch 283 of 800 took 78.189s
# Epoch 284 of 800 took 78.355s
# Epoch 285 of 800 took 78.475s
# Epoch 286 of 800 took 78.515s
# Epoch 287 of 800 took 78.294s
# Epoch 288 of 800 took 78.465s
# Epoch 289 of 800 took 78.448s
# Epoch 290 of 800 took 78.148s
# Epoch 291 of 800 took 78.446s
# Epoch 292 of 800 took 78.450s
# Epoch 293 of 800 took 78.360s
# Epoch 294 of 800 took 78.453s
# Epoch 295 of 800 took 78.289s
# Epoch 296 of 800 took 78.326s
# Epoch 297 of 800 took 78.242s
# Epoch 298 of 800 took 78.420s
# Epoch 299 of 800 took 78.112s
# Epoch 300 of 800 took 78.272s
# Epoch 301 of 800 took 78.501s
# Epoch 302 of 800 took 78.524s
# Epoch 303 of 800 took 78.459s
# Epoch 304 of 800 took 78.524s
# Epoch 305 of 800 took 78.363s
# Epoch 306 of 800 took 78.368s
# Epoch 307 of 800 took 78.322s
# Epoch 308 of 800 took 78.471s
# Epoch 309 of 800 took 78.082s
# Epoch 310 of 800 took 78.205s
# Epoch 311 of 800 took 78.372s
# Epoch 312 of 800 took 78.500s
# Epoch 313 of 800 took 78.499s
# Epoch 314 of 800 took 77.810s
# Epoch 315 of 800 took 78.402s
# Epoch 316 of 800 took 78.495s
# Epoch 317 of 800 took 78.451s
# Epoch 318 of 800 took 78.188s
# Epoch 319 of 800 took 78.411s
# Epoch 320 of 800 took 78.503s
# Epoch 321 of 800 took 78.056s
# Epoch 322 of 800 took 78.533s
# Epoch 323 of 800 took 78.480s
# Epoch 324 of 800 took 78.458s
# Epoch 325 of 800 took 78.374s
# Epoch 326 of 800 took 78.421s
# Epoch 327 of 800 took 78.107s
# Epoch 328 of 800 took 78.234s
# Epoch 329 of 800 took 78.465s
# Epoch 330 of 800 took 78.422s
# Epoch 331 of 800 took 78.415s
# Epoch 332 of 800 took 78.519s
# Epoch 333 of 800 took 78.440s
# Epoch 334 of 800 took 78.517s
# Epoch 335 of 800 took 77.392s
# Epoch 336 of 800 took 78.467s
# Epoch 337 of 800 took 78.379s
# Epoch 338 of 800 took 78.264s
# Epoch 339 of 800 took 78.274s
# Epoch 340 of 800 took 78.530s
# Epoch 341 of 800 took 77.957s
# Epoch 342 of 800 took 78.394s
# Epoch 343 of 800 took 78.522s
# Epoch 344 of 800 took 78.036s
# Epoch 345 of 800 took 77.825s
# Epoch 346 of 800 took 78.363s
# Epoch 347 of 800 took 78.485s
# Epoch 348 of 800 took 78.494s
# Epoch 349 of 800 took 78.465s
# Epoch 350 of 800 took 78.066s
# Epoch 351 of 800 took 78.513s
# Epoch 352 of 800 took 78.500s
# Epoch 353 of 800 took 78.455s
# Epoch 354 of 800 took 78.063s
# Epoch 355 of 800 took 78.036s
# Epoch 356 of 800 took 78.524s
# Epoch 357 of 800 took 78.320s
# Epoch 358 of 800 took 78.001s
# Epoch 359 of 800 took 78.282s
# Epoch 360 of 800 took 78.224s
# Epoch 361 of 800 took 77.914s
# Epoch 362 of 800 took 78.539s
# Epoch 363 of 800 took 78.372s
# Epoch 364 of 800 took 78.584s
# Epoch 365 of 800 took 78.048s
# Epoch 366 of 800 took 78.525s
# Epoch 367 of 800 took 78.496s
# Epoch 368 of 800 took 78.181s
# Epoch 369 of 800 took 78.544s
# Epoch 370 of 800 took 78.436s
# Epoch 371 of 800 took 78.496s
# Epoch 372 of 800 took 78.346s
# Epoch 373 of 800 took 78.399s
# Epoch 374 of 800 took 77.917s
# Epoch 375 of 800 took 78.377s
# Epoch 376 of 800 took 78.407s
# Epoch 377 of 800 took 78.480s
# Epoch 378 of 800 took 78.473s
# Epoch 379 of 800 took 77.729s
# Epoch 380 of 800 took 77.707s
# Epoch 381 of 800 took 77.968s
# Epoch 382 of 800 took 78.287s
# Epoch 383 of 800 took 78.137s
# Epoch 384 of 800 took 78.470s
# Epoch 385 of 800 took 78.464s
# Epoch 386 of 800 took 78.476s
# Epoch 387 of 800 took 78.420s
# Epoch 388 of 800 took 77.954s
# Epoch 389 of 800 took 78.105s
# Epoch 390 of 800 took 78.413s
# Epoch 391 of 800 took 78.003s
# Epoch 392 of 800 took 78.604s
# Epoch 393 of 800 took 78.563s
# Epoch 394 of 800 took 78.029s
# Epoch 395 of 800 took 78.313s
# Epoch 396 of 800 took 78.507s
# Epoch 397 of 800 took 78.470s
# Epoch 398 of 800 took 78.587s
# Epoch 399 of 800 took 78.605s
# Epoch 400 of 800 took 78.371s
# Epoch 401 of 800 took 78.592s
# Epoch 402 of 800 took 78.684s
# Epoch 403 of 800 took 78.521s
# Epoch 404 of 800 took 78.634s
# Epoch 405 of 800 took 78.529s
# Epoch 406 of 800 took 78.453s
# Epoch 407 of 800 took 78.625s
# Epoch 408 of 800 took 78.358s
# Epoch 409 of 800 took 78.666s
# Epoch 410 of 800 took 78.518s
# Epoch 411 of 800 took 78.144s
# Epoch 412 of 800 took 78.483s
# Epoch 413 of 800 took 78.044s
# Epoch 414 of 800 took 78.420s
# Epoch 415 of 800 took 78.002s
# Epoch 416 of 800 took 78.209s
# Epoch 417 of 800 took 77.672s
# Epoch 418 of 800 took 78.553s
# Epoch 419 of 800 took 77.939s
# Epoch 420 of 800 took 78.290s
# Epoch 421 of 800 took 78.089s
# Epoch 422 of 800 took 78.503s
# Epoch 423 of 800 took 78.483s
# Epoch 424 of 800 took 78.404s
# Epoch 425 of 800 took 78.267s
# Epoch 426 of 800 took 77.949s
# Epoch 427 of 800 took 78.531s
# Epoch 428 of 800 took 77.587s
# Epoch 429 of 800 took 78.532s
# Epoch 430 of 800 took 78.476s
# Epoch 431 of 800 took 78.551s
# Epoch 432 of 800 took 78.396s
# Epoch 433 of 800 took 78.489s
# Epoch 434 of 800 took 78.434s
# Epoch 435 of 800 took 78.546s
# Epoch 436 of 800 took 78.508s
# Epoch 437 of 800 took 78.534s
# Epoch 438 of 800 took 78.444s
# Epoch 439 of 800 took 78.023s
# Epoch 440 of 800 took 78.664s
# Epoch 441 of 800 took 78.323s
# Epoch 442 of 800 took 78.741s
# Epoch 443 of 800 took 77.999s
# Epoch 444 of 800 took 78.574s
# Epoch 445 of 800 took 78.371s
# Epoch 446 of 800 took 78.526s
# Epoch 447 of 800 took 78.533s
# Epoch 448 of 800 took 78.077s
# Epoch 449 of 800 took 78.562s
# Epoch 450 of 800 took 77.986s
# Epoch 451 of 800 took 78.511s
# Epoch 452 of 800 took 78.225s
# Epoch 453 of 800 took 78.542s
# Epoch 454 of 800 took 77.798s
# Epoch 455 of 800 took 77.873s
# Epoch 456 of 800 took 78.505s
# Epoch 457 of 800 took 78.575s
# Epoch 458 of 800 took 78.603s
# Epoch 459 of 800 took 78.551s
# Epoch 460 of 800 took 78.380s
# Epoch 461 of 800 took 78.291s
# Epoch 462 of 800 took 78.568s
# Epoch 463 of 800 took 78.488s
# Epoch 464 of 800 took 78.560s
# Epoch 465 of 800 took 78.538s
# Epoch 466 of 800 took 78.266s
# Epoch 467 of 800 took 78.556s
# Epoch 468 of 800 took 78.442s
# Epoch 469 of 800 took 78.557s
# Epoch 470 of 800 took 78.442s
# Epoch 471 of 800 took 78.549s
# Epoch 472 of 800 took 78.367s
# Epoch 473 of 800 took 78.365s
# Epoch 474 of 800 took 78.533s
# Epoch 475 of 800 took 78.289s
# Epoch 476 of 800 took 78.166s
# Epoch 477 of 800 took 78.203s
# Epoch 478 of 800 took 78.343s
# Epoch 479 of 800 took 78.418s
# Epoch 480 of 800 took 78.515s
# Epoch 481 of 800 took 77.824s
# Epoch 482 of 800 took 78.054s
# Epoch 483 of 800 took 77.393s
# Epoch 484 of 800 took 78.767s
# Epoch 485 of 800 took 78.650s
# Epoch 486 of 800 took 78.725s
# Epoch 487 of 800 took 78.207s
# Epoch 488 of 800 took 78.249s
# Epoch 489 of 800 took 78.640s
# Epoch 490 of 800 took 78.892s
# Epoch 491 of 800 took 78.434s
# Epoch 492 of 800 took 78.003s
# Epoch 493 of 800 took 78.710s
# Epoch 494 of 800 took 78.783s
# Epoch 495 of 800 took 77.930s
# Epoch 496 of 800 took 78.689s
# Epoch 497 of 800 took 78.823s
# Epoch 498 of 800 took 78.461s
# Epoch 499 of 800 took 78.298s
# Epoch 500 of 800 took 78.520s
# Epoch 501 of 800 took 78.714s
# Epoch 502 of 800 took 78.668s
# Epoch 503 of 800 took 78.687s
# Epoch 504 of 800 took 78.667s
# Epoch 505 of 800 took 78.718s
# Epoch 506 of 800 took 77.960s
# Epoch 507 of 800 took 78.666s
# Epoch 508 of 800 took 78.664s
# Epoch 509 of 800 took 78.088s
# Epoch 510 of 800 took 78.719s
# Epoch 511 of 800 took 78.669s
# Epoch 512 of 800 took 78.541s
# Epoch 513 of 800 took 78.463s
# Epoch 514 of 800 took 78.730s
# Epoch 515 of 800 took 78.313s
# Epoch 516 of 800 took 78.168s
# Epoch 517 of 800 took 78.372s
# Epoch 518 of 800 took 78.729s
# Epoch 519 of 800 took 78.697s
# Epoch 520 of 800 took 78.026s
# Epoch 521 of 800 took 78.289s
# Epoch 522 of 800 took 78.709s
# Epoch 523 of 800 took 78.693s
# Epoch 524 of 800 took 78.509s
# Epoch 525 of 800 took 78.702s
# Epoch 526 of 800 took 78.696s
# Epoch 527 of 800 took 78.685s
# Epoch 528 of 800 took 78.074s
# Epoch 529 of 800 took 78.223s
# Epoch 530 of 800 took 78.702s
# Epoch 531 of 800 took 78.150s
# Epoch 532 of 800 took 78.641s
# Epoch 533 of 800 took 78.287s
# Epoch 534 of 800 took 78.545s
# Epoch 535 of 800 took 78.655s
# Epoch 536 of 800 took 78.600s
# Epoch 537 of 800 took 78.619s
# Epoch 538 of 800 took 78.661s
# Epoch 539 of 800 took 78.263s
# Epoch 540 of 800 took 78.585s
# Epoch 541 of 800 took 77.818s
# Epoch 542 of 800 took 78.482s
# Epoch 543 of 800 took 78.632s
# Epoch 544 of 800 took 78.688s
# Epoch 545 of 800 took 78.530s
# Epoch 546 of 800 took 78.347s
# Epoch 547 of 800 took 78.572s
# Epoch 548 of 800 took 78.476s
# Epoch 549 of 800 took 78.660s
# Epoch 550 of 800 took 78.675s
# Epoch 551 of 800 took 78.188s
# Epoch 552 of 800 took 78.555s
# Epoch 553 of 800 took 78.482s
# Epoch 554 of 800 took 78.666s
# Epoch 555 of 800 took 78.188s
# Epoch 556 of 800 took 78.545s
# Epoch 557 of 800 took 78.476s
# Epoch 558 of 800 took 78.652s
# Epoch 559 of 800 took 78.572s
# Epoch 560 of 800 took 77.983s
# Epoch 561 of 800 took 78.569s
# Epoch 562 of 800 took 78.443s
# Epoch 563 of 800 took 78.420s
# Epoch 564 of 800 took 78.685s
# Epoch 565 of 800 took 78.681s
# Epoch 566 of 800 took 78.628s
# Epoch 567 of 800 took 78.606s
# Epoch 568 of 800 took 78.677s
# Epoch 569 of 800 took 78.423s
# Epoch 570 of 800 took 78.455s
# Epoch 571 of 800 took 78.621s
# Epoch 572 of 800 took 78.665s
# Epoch 573 of 800 took 78.019s
# Epoch 574 of 800 took 78.650s
# Epoch 575 of 800 took 78.189s
# Epoch 576 of 800 took 78.699s
# Epoch 577 of 800 took 78.592s
# Epoch 578 of 800 took 78.590s
# Epoch 579 of 800 took 77.085s
# Epoch 580 of 800 took 78.535s
# Epoch 581 of 800 took 78.338s
# Epoch 582 of 800 took 78.073s
# Epoch 583 of 800 took 78.594s
# Epoch 584 of 800 took 78.572s
# Epoch 585 of 800 took 78.587s
# Epoch 586 of 800 took 78.581s
# Epoch 587 of 800 took 78.254s
# Epoch 588 of 800 took 78.592s
# Epoch 589 of 800 took 78.388s
# Epoch 590 of 800 took 78.577s
# Epoch 591 of 800 took 78.449s
# Epoch 592 of 800 took 78.627s
# Epoch 593 of 800 took 78.550s
# Epoch 594 of 800 took 78.395s
# Epoch 595 of 800 took 78.465s
# Epoch 596 of 800 took 78.394s
# Epoch 597 of 800 took 78.396s
# Epoch 598 of 800 took 78.596s
# Epoch 599 of 800 took 78.683s
# Epoch 600 of 800 took 78.633s
# Epoch 601 of 800 took 78.636s
# Epoch 602 of 800 took 78.572s
# Epoch 603 of 800 took 77.603s
# Epoch 604 of 800 took 78.594s
# Epoch 605 of 800 took 78.421s
# Epoch 606 of 800 took 78.401s
# Epoch 607 of 800 took 78.606s
# Epoch 608 of 800 took 78.607s
# Epoch 609 of 800 took 78.606s
# Epoch 610 of 800 took 78.578s
# Epoch 611 of 800 took 78.220s
# Epoch 612 of 800 took 78.562s
# Epoch 613 of 800 took 78.529s
# Epoch 614 of 800 took 77.871s
# Epoch 615 of 800 took 78.043s
# Epoch 616 of 800 took 78.675s
# Epoch 617 of 800 took 78.314s
# Epoch 618 of 800 took 78.687s
# Epoch 619 of 800 took 78.570s
# Epoch 620 of 800 took 78.610s
# Epoch 621 of 800 took 78.369s
# Epoch 622 of 800 took 78.688s
# Epoch 623 of 800 took 78.608s
# Epoch 624 of 800 took 78.701s
# Epoch 625 of 800 took 78.640s
# Epoch 626 of 800 took 78.429s
# Epoch 627 of 800 took 77.687s
# Epoch 628 of 800 took 78.527s
# Epoch 629 of 800 took 78.175s
# Epoch 630 of 800 took 77.857s
# Epoch 631 of 800 took 78.594s
# Epoch 632 of 800 took 78.621s
# Epoch 633 of 800 took 78.211s

# %%
network.save('../weights', '3cascades_not_clear_trained800')
